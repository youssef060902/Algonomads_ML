# %% [markdown]
# #KNN

# %%
import pandas as pd

# Tableau simplifié et parfaitement visible dans Jupyter
data = {
    "Élément": [
        "Variables impliquées",
        "Paramètres",
        "Hyperparamètres"
    ],
    
    "Contenu": [
        "30 features (mean, se, worst) du dataset WDBC",
        
        "Distance : L1 & L2\nNombre de voisins : 1 (1-NN)",
        
        "Aucun hyperparamètre d’apprentissage\nEpochs = 1 (pas un entraînement)"
    ]
}

df_nn = pd.DataFrame(data)

df_nn.style.set_properties(**{
    'white-space': 'pre-wrap',  # Affiche multi-lignes
    'text-align': 'left'
})
# Out:
# <style type="text/css">
# #T_00596_row0_col0, #T_00596_row0_col1, #T_00596_row1_col0, #T_00596_row1_col1, #T_00596_row2_col0, #T_00596_row2_col1 {
#   white-space: pre-wrap;
#   text-align: left;
# }
# </style>
# <table id="T_00596">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00596_level0_col0" class="col_heading level0 col0" >Élément</th>
#       <th id="T_00596_level0_col1" class="col_heading level0 col1" >Contenu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00596_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_00596_row0_col0" class="data row0 col0" >Variables impliquées</td>
#       <td id="T_00596_row0_col1" class="data row0 col1" >30 features (mean, se, worst) du dataset WDBC</td>
#     </tr>
#     <tr>
#       <th id="T_00596_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_00596_row1_col0" class="data row1 col0" >Paramètres</td>
# ...
