# %% [markdown]
# #Project_ML

# %% [markdown]
# | Élément                | Contenu court |
# |------------------------|---------------|
# | Variables impliquées   | 30 features du WDBC (ex. radius, texture, area, perimeter, etc.) |
# | Paramètres             | w (poids) et b (biais) — hyperplan : f(x) = w·x + b |
# | Hyperparamètres        | C (régularisation), learning rate, standardisation, epochs |
